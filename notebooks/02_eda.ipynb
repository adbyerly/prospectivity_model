# %% [markdown]
# # **Mineral Prospectivity Project**
# ## 02 exploratory data analysis
#
# goals:\
# -create plots and maps to investigate distributions, correlations and spatial trends

# %% [markdown]
# ### Part 1. import packages and identify local directory
# a. import packages needed for data loading and analysis

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import glob
import os

data_path = "/Users/adbyerly/prospectivity_model/data/processed/"

# %% [markdown]
# ### Part 2. load processed data and document observations

# %% [markdown]
# a. load processed data from Idaho Geologic Survey mines database\
# -load data

# %%
mines_gdf_processed = gpd.read_file(data_path "idaho_gold_mines.geojson")

# %% [markdown]
# b. load processed geochemical data from the "USGS National Geochemical Database (NGDB)"\
# -load data\
# -investigate

# %%
# csv - load all geochemical files from the downloaded folder into a dictionary
files = glob.glob(data_path + "processed/NGDB/*.csv")
ngdb_dfs={}
