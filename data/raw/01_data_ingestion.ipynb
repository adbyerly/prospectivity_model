# %% [markdown]
# # **Mineral Prospectivity Project**
# ## 01 data ingestion
#
# goal:
# -load relevant USGS data

# %% [markdown]
# ### import packages

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

data_path = "/Users/adbyerly/prospectivity_model/data"
